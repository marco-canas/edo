# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/intro-Machine-Learning/blob/main/examples_bank/6_clasificacion/asignacion_parcial_2_regresion_clasificacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# # Ecuaciones exactas

# %% [markdown]
# ## Preconceptos
#
# * Cálculo de varias variables
# * Derivación parcial.
# * Diferencial de una función de dos variables.

# %% [markdown]
# ## Introducción

# %% [markdown]
# $$ ydx + xdy = 0 $$

# %% [markdown]
# $$ d(xy) = ydx + xdy = 0  $$

# %% [markdown]
# $$ xy = c $$

# %%
import numpy as np 
import matplotlib.pyplot as plt 

C = np.arange(-3,4)

x = np.linspace(-3,3)
y = np.linspace(-3,3)
X,Y = np.meshgrid(x,y)

F = X*Y
for c in C:
    G = c
    plt.contour(X,Y,(F-G))

# %% [markdown]
# ## Objetivo de la clase
#
# * estudiar ecuaciones de primer orden en forma diferencial:
#
# $$ M(x,y)dx + N(x,y)dy = 0 $$

# %% [markdown]
# ## Ejemplo:
#
# $$ x^{2} - 5xy + y^{3} = c, $$
#
# $$ (2x - 5y)dx + (-5x + 3y^{2})dy = 0 $$

# %% [markdown]
# ## Definición de ecuación exacta

# %% [markdown]
# Una expresión diferencial $M(x, y)dx + N(x, y)dy$ es una diferencial exacta en una región $R$ del plano $xy$ si ésta corresponde a la diferencial de alguna función $f(x, y)$ definida en $R$.
#
# Una ecuación diferencial de primer orden de la forma
#
# $$ M(x,y)dx + N(x,y)dy = 0 $$
#
# se dice que es una **ecuación exacta** si la expresión del lado izquierdo es una diferencial exacta.

# %% [markdown]
# ## Teorema: Criterio para una diferencial exacta

# %% [markdown]
# Sean $M(x, y)$ y $N(x, y)$ continuas y que tienen primeras derivadas parciales continuas en una región rectangular $R$ definida por $a < x < b$, $c<y<d$.
#
# Entonces una condición necesaria y suficiente para que $M(x, y) dx + N(x, y) dy$ sea una
# diferencial exacta es
#
# $$ \frac{\partial M}{\partial y} = \frac{\partial N}{\partial x} $$

# %% [markdown]
# ## Método de solución
